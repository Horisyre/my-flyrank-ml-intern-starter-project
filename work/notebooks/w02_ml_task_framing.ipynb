# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Horisyre/my-flyrank-ml-intern-starter-project/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Clustering is an exploratory learning technique that groups similar pages
# based on shared characteristics. Although the resulting clusters could be
# interpreted as pages that may or may not require refreshing, the algorithm
# does not assign these labels automatically. Interpreting what each cluster
# represents requires domain knowledge, making clustering a less suitable
# approach for this analysis.

# Classification would require predefined categories such as "Refresh" or
# "Do not refresh", which are not available in this dataset. One approach
# would be to manually define these labels  based on a defined set of rules for the training data and train a
# classification model to predict them. The model's performance could then be
# evaluated to determine how well it classifies unseen pages into the defined
# categories.

# A scoring model would also require domain expertise to determine how much
# each feature should contribute to the final score. Without established
# business rules or validated feature weights, the resulting score would be
# subjective. 


# A ranking approach can be used to observe
# relationships between the features to estimate a page's Google Search
# ranking (gsc_avg_position), allowing pages to be ordered by their expected
# search performance. 
# This is useful because if a client doesn't have Google Search Console, they won't have gsc_avg_position
# They can use a model like this to estimate average position


# I have only included features that are highly correlated and may introduce bias for applicable models,
# therefore i must factor this in to whether i will be using classication,clustering,ranking or scoring.
# It is important that I add in features that will enable the model to learn from unseen data.





# In conclusions, of the available approaches, I would choose a ranking model.
# Although classification could be used by defining categories such as
# "Refresh" or "Do not refresh", this would require manually creating labels
# based on business rules. A similar rule-based approach was already explored
# in the previous assignment.
#
# A ranking model adds more value because it estimates a page's expected
# Google Search ranking (gsc_avg_position) using the identified search and
# engagement signals. The predicted rankings can then be used to order pages
# by their expected search performance and may also provide useful estimates
# for pages or clients where ranking information is unavailable.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# The model would ne used to rank the data and compare against gsc_avg_position, an observed outcome

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
