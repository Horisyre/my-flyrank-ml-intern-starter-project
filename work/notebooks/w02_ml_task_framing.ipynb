# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Horisyre/my-flyrank-ml-intern-starter-project/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# Clustering is an exploratory learning technique that groups similar pages
# based on shared characteristics. Although the resulting clusters could be
# interpreted as pages that may or may not require refreshing, the algorithm
# does not assign these labels automatically. Interpreting what each cluster
# represents requires domain knowledge, making clustering a less suitable
# approach for this analysis.

# Classification would require predefined categorical data such as "Refresh" or
# "Do not refresh", which are available in this dataset. One approach
# would be train the model on the training data and check the performance of the model on unseen data. 
# The model's performance could then be
# evaluated to determine how well it classifies unseen pages into the defined
# categories.

# A scoring model would also require domain expertise to determine how much
# each feature should contribute to the final score. Without established
# business rules or validated feature weights, the resulting score would be
# subjective. 


# A ranking approach can be used to observe
# relationships between the features to estimate a page's search
# ranking (avg_position), allowing pages to be ordered by their expected
# search performance. 
# However this approach may struggle to learn how to predict the average position especially since serach sigals and engagement signals are not the only factors that 
# determine a page's ranking.



# In conclusions, of the available approaches, I would choose a classification model.
# A similar rule-based approach was already explored
# in the previous assignment. So I would like to explore a similar approach using a classification model to see 
# if it can learn the relationship between the features and the target variable, "impression_tier", without requiring explicit rules or thresholds to be defined in advance.
#
# I have chosen this method due to the following reason:
# The relationship between the features and the target variable is known where we see impressions_90 in the numerical dataset, which may suggest that the target variable is a
# has been derived from this feature.
# The other models require either domain knowledge (which i'm not fully knowledgeable about), business rules to be defined in advance,
# or uncertainty in the relationship between the features and the target variable.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# The model would be used to validate the relationship between features and the observed outcome, "impression_tier", by learning from the data provided. 
# The model would be able to predict the impression tier for unseen pages based on the features provided, without requiring explicit rules or thresholds to be defined in advance.
# This approach allows for a more flexible and data-driven solution to the problem of classifying pages based on their visibility and performance in search results.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# Since we are using a classifier, we can use evaulation metrics like accuracy, precision, recall, and F1 score to assess the model's performance. 
# These metrics will help us understand how well the model is able to classify pages into the correct impression tiers based on the features provided.

# Ideally, I would like each evaluation metric to achieve a score of at least 0.70.
# However, these metrics still need to be evaluated to ensure theres no bias etc. 
# Therefore, I will be using a confusion matrix to visualize the model's performance and identify any potential issues with the classification results.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# since our inital signal analysis was performed on integer type variables only, 
# we will attempt to only use numeric variables for models input
numeric_df = df.select_dtypes(include="number")
print(numeric_df.head())


# Here we see one row represents one piece of content (one page/article) with its associated metrics.
# metrics vary from visibility,engagement,movement,ranking.

# For my specific lane I will be focussing on using search performance metrics and correlated features to classify the impression rating of a page, 
# and prove of the association of search signals and the visibility of pages in search results.
# Out:
#    search_volume  competition   cpc  word_count  char_count  impressions_90d  \
# 0           10.0         0.67  2.05      3221.0     20457.0             3803
# 1           90.0         0.01  0.05      2481.0     15562.0            15320
# 2            0.0         0.00  0.00      3515.0     23643.0            12581
# 3           10.0         0.00  0.00         NaN         NaN            11751
# 4            0.0         0.00  0.00      2803.0     17469.0            19140
#
#    clicks_90d  pageviews_90d  sessions_90d  users_90d  ...  sessions_prev_30d  \
# 0          29             22            17         16  ...                  9
# 1           7             10             9          9  ...                  2
# 2          11             14            11         11  ...                  3
# 3          58             87            78         75  ...                 26
# 4          24            177           145        144  ...                  9
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# A classifier is useful when the relationship is not explicitly programmed.
# In my research project, I am not trying to rediscover the thresholds for the impression tier. I am trying to answer:

# Can search signals and content features be used to classify a page's visibility?
# The model learns the relationship from the data provided rather explicitly being given the rules.

# If i used an if–else statement it would require me to know the decision rules in advance.
# In my case, its not that there are too many or too little features, but rather that the relationship between the features and the target variable is not known 
# and could potentially be complex. Therefore, a classifier is a better approach than an if–else statement.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
